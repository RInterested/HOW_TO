# %%
d = read.table(text="          value time treat
    1  8.788269    1     0
    2  7.964719    6     0
    3  8.204051   12     0
    4  9.041368   24     0
    5  8.181555   48     0
    6  8.041419   96     0
    7  7.992336  144     0
    8  7.948658    1     1
    9  8.090211    6     1
    10 8.031459   12     1
    11 8.118308   24     1
    12 7.699051   48     1
    13 7.537120   96     1
    14 7.268570  144     1", header=T)

# %%
d
# Out:
#    value    time treat
# 1  8.788269   1  0
# 2  7.964719   6  0
# 3  8.204051  12  0
# 4  9.041368  24  0
# 5  8.181555  48  0
# 6  8.041419  96  0
# 7  7.992336 144  0
# 8  7.948658   1  1
# 9  8.090211   6  1
# 10 8.031459  12  1
# 11 8.118308  24  1
# 12 7.699051  48  1
# 13 7.537120  96  1
# 14 7.268570 144  1

# %%
summary(lm(value~time*treat,data=d))
# Out:
# Call:
# lm(formula = value ~ time * treat, data = d)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.50627 -0.12345  0.00296  0.04124  0.63785
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  8.493476   0.156345  54.325 1.08e-13 ***
# time        -0.003748   0.002277  -1.646   0.1307
# treat       -0.411271   0.221106  -1.860   0.0925 .
# time:treat  -0.001938   0.003220  -0.602   0.5606
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.3 on 10 degrees of freedom
# Multiple R-squared:  0.6526,	Adjusted R-squared:  0.5484
# F-statistic: 6.262 on 3 and 10 DF,  p-value: 0.01154

# %%
 summary(aov(value~time*treat,data=d))
# Out:
#             Df Sum Sq Mean Sq F value Pr(>F)
# time         1 0.7726  0.7726   8.586 0.0150 *
# treat        1 0.8852  0.8852   9.837 0.0106 *
# time:treat   1 0.0326  0.0326   0.362 0.5606
# Residuals   10 0.8998  0.0900
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
options(repr.plot.width=4, repr.plot.height=3)
par(tcl = -0.1)
plot(value ~ time, d, pch = 19, col=rgb(.1,.1,.9,.7) , cex=.5, bg=rgb(.5,.2,.1,.3),
    cex.lab=.7, cex.axis=.7, main = "Playing with Jupyter", cex.main = .8)
# Out:
# Plot with title "Playing with Jupyter"

# %%
install.packages('dplyr', repos='http://cran.us.r-project.org')
library(dplyr)
# Out:
# also installing the dependencies 'DBI', 'BH'
# package 'DBI' successfully unpacked and MD5 sums checked
# package 'BH' successfully unpacked and MD5 sums checked
# package 'dplyr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\vRad\AppData\Local\Temp\RtmpErSqgp\downloaded_packages
# Warning message:
# "package 'dplyr' was built under R version 3.3.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
plot(iris)
# Out:
# plot without title

# %%
glm(mtcars$cyl ~ mtcars$mpg, family="poisson")
# Out:
# Call:  glm(formula = mtcars$cyl ~ mtcars$mpg, family = "poisson")
#
# Coefficients:
# (Intercept)   mtcars$mpg
#     2.68570     -0.04461
#
# Degrees of Freedom: 31 Total (i.e. Null);  30 Residual
# Null Deviance:	    16.57
# Residual Deviance: 4.282 	AIC: 124.9

# %%
n <- 10 
s <- 2.7 

x <- rnorm(n) 
e <- rnorm(n,sd=s)
y <- 0.3 + 1.2*x + e

model <- lm(y ~ x) 
r <- model$res 

summary( lm(e ~ r) )
# Out:
# Call:
# lm(formula = e ~ r)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -1.921 -1.495 -0.485  1.541  2.488
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.1322     0.5746  -0.230  0.82385
# r             1.0000     0.2337   4.278  0.00269 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.817 on 8 degrees of freedom
# Multiple R-squared:  0.6959,	Adjusted R-squared:  0.6579
# F-statistic:  18.3 on 1 and 8 DF,  p-value: 0.002693

# %%
library(heatmap3)
m = matrix(rnorm(1000),ncol=100)
heatmap3(cor(m))
# Out:
# Error in library(heatmap3): there is no package called 'heatmap3'
# Traceback:
#
# 1. library(heatmap3)
# 2. stop(txt, domain = NA)

# %%
install.packages('heatmap3', repos='http://cran.us.r-project.org')
# Out:
# also installing the dependency 'fastcluster'
# package 'fastcluster' successfully unpacked and MD5 sums checked
# package 'heatmap3' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\vRad\AppData\Local\Temp\RtmpErSqgp\downloaded_packages

# %%
options(repr.plot.width=10, repr.plot.height=10) # Without this I was getting error meassage.
require(heatmap3)
m = matrix(rnorm(1000),ncol=100)
heatmap3(cor(m), main="heatmap")
# Out:
# Plot with title "heatmap"
